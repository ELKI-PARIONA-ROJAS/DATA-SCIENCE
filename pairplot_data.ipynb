# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('datito/data_categorica.csv', index_col=0)

# %%
sns.pairplot(data, hue="Tiempo_Exacto", palette = ['r', 'b'])
plt.show()
